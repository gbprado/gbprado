# %% [markdown]
# <a href="https://colab.research.google.com/github/gbprado/gbprado/blob/main/Testes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
''' PRIMEIRO PROJETO COM PYTHON '''

'''
O programa deve:
Pedir o nome do usuário (string)

Pedir a idade (converter para int)

Pedir o salário mensal (converter para float)

Perguntar quantos meses a pessoa trabalha no ano (int)
'''

texto = ' tha lopez dias '
texto = texto.strip().replace('z','s').upper()
texto

texto = " A FLOR E AZUL "
tetxo = texto.strip().replace('e', 'é').lower
texto

###############################################

''' USANDO ISSO COMO BASE, FAZER A TAREFA ACIMA '''

nome = input('Digite seu nome: ')
idade = int(input('Digite sua idade: '))
salario_mensal = float(input('Digite seu Salario mensal: '))
meses_trabalhados_no_ano = int(input('Digite quantos meses trabalhados no ano: '))
# Out:
# Digite seu nome: Gabriel Prado
# Digite sua idade: 23
# Digite seu Salario mensal: 2400
# Digite quantos meses trabalhados no ano: 3

# %%
'''
Coleta e amostragem de dados
Crie um programa que solicite à pessoa usuária digitar seu nome, e imprima “Olá, [nome]!”.
Crie um programa que solicite à pessoa usuária digitar seu nome e idade, e imprima “Olá, [nome], você tem [idade] anos.”.
Crie um programa que solicite à pessoa usuária digitar seu nome, idade e altura em metros, e imprima “Olá, [nome], você tem [idade] anos e mede [altura] metros!”.'''

####

nome = input('Digite seu nome: ')
print(str(f'Olá, {nome}!'))

# Correção para pedir nome e idade separadamente
nome_idade = input('Digite seu nome: ')
idade = int(input('Digite sua idade: '))
print(str(f'Olá, {nome_idade}, você tem {idade} anos.'))
# Out:
# Digite seu nome: Gabriel
# Olá, Gabriel!
# Digite seu nome: Gabriel
# Digite sua idade: 23
# Olá, Gabriel, você tem 23 anos.

# %%
nome_idade = input('Digite seu nome: ')
idade = int(input('Digite sua idade: '))
print(f'Olá {nome_idade}, você tem {idade} anos.')
# Out:
# Digite seu nome: Gabriel Matheus
# Digite sua idade: 23
# Olá Gabriel Matheus, você tem 23 anos.

# %%
Soma_1 = int(input('Digite o número 1: '))
Soma_2 = int(input('Digite o número 2: '))

Soma = Soma_1 + Soma_2
print(f'O valor da sua conta é = {Soma}')
# Out:
# Digite o número 1: 3
# Digite o número 2: 2
# O valor da sua conta é = 5
